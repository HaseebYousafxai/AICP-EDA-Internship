# %% [markdown]
# # **AI Community Pakistan Linkedin**
# [![LinkedIn](https://img.icons8.com/color/48/000000/linkedin.png)](https://www.linkedin.com/company/aicommunitypakistan/?lipi=urn%3Ali%3Apage%3Ad_flagship3_search_srp_all%3ByA3ec4yFR22MbTcVPUhSBA%3D%3D)

# %% [markdown]
# # **My Linkedin and Twitter profile**
# [![LinkedIn](https://img.icons8.com/color/48/000000/linkedin.png)](www.linkedin.com/in/haseeb-ahmad-160845286)
# [![Twitter](https://img.icons8.com/color/48/000000/twitter.png)](https://twitter.com/haseebyosafxai)

# %% [markdown]
# # **EDA Internship Task Week 4**

# %% [markdown]
#  **Task 01**
# > Import libraries (Numpy, pandas, matplotlib, plotly and seaborn) and then read csv file:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# > **Import Datatset**

# %%
df = pd.read_csv("menu.csv")

# %% [markdown]
#  **Task 02**
# > Check statistical facts by checking all columns. Then calculate the maximum value of the following
# attributes ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (%
# Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']:

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# > **Explanation**
# - the above code was used for checking the `statistical summary` of the dataset:
# - keep in mind that statistical analysis is only for numerical columns of the dataset:

# %%
 
attributes = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein',
              'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

max_values = df[attributes].max()

print("Maximum values:",max_values)
# Out:
# Maximum values: Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %% [markdown]
# > **Explanation**
# - In the above code section first we select the specific attributes/columns from the dataset and store in the variabkle name as `attributes`:
# - Then we apply `.max()` function of  pandas library to find the maximum value in each column.

# %% [markdown]
#  **Task 03**
# > Check to see if infact there is any correlation between Calories and other independent variables by
# plotting a correlation matrix next:

# %%
correlation_matrix = df[attributes].corr()

# Create a heatmap for the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
#  **Task 04**
# > Draw boxplot for Calories vs Category to spot outliers and max calories category:

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='Calories', y='Category', data=df, hue='Category', palette='Set2', width=0.8, linewidth=1.5, notch=True, legend=False)
plt.xlabel = 'Categories'
plt.ylabel = 'Calories'
plt.title('Box Plot of Calories vs Category')
plt.show()

# %% [markdown]
#  **Task 05**
# >  Figure out which exact item contains a high quantity for ['Calories', 'Total Fat', 'Carbohydrates',
# 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium
# (% Daily Value)', 'Iron (% Daily Value)':

# %%
total_nutrients = df[['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars',
                       'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                       'Calcium (% Daily Value)', 'Iron (% Daily Value)']].sum()

# %% [markdown]
# **Explanation**
# - Calculate the sum of each nutrient for all items

# %%
high_quantity_items = df.loc[df[total_nutrients.idxmax()] == df[total_nutrients.idxmax()].max()]

# %% [markdown]
# **Explanation:**
# - This part is modified. It still finds the item with the highest quantity for each nutrient, but the approach is different.
# - It checks if the maximum value of each nutrient column in the dataset is equal to the maximum value of the sum of nutrients.
# - Essentially, it finds items where the maximum value of any nutrient matches the overall maximum sum of nutrients.

# %%
print("Items with high quantity:\n",high_quantity_items[['Item', 'Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars',
                            'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                            'Calcium (% Daily Value)', 'Iron (% Daily Value)']])
# Out:
# Items with high quantity:
#                              Item  Calories  Total Fat  Carbohydrates  \
# 82  Chicken McNuggets (40 piece)      1880      118.0            118
#
#     Dietary Fiber  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82              6       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25

# %% [markdown]
# Item Name:
#
# The item with the highest quantity is `Chicken McNuggets (40 piece)`.

# %% [markdown]
#  **Task 06**
# > : Draw Stripplot for each
# category against the following
# attributes ['Calories', 'Total Fat',
# 'Carbohydrates', 'Dietary
# Fiber', 'Sugars', 'Protein',
# 'Vitamin A (% Daily Value)',
# 'Vitamin C (% Daily Value)',
# 'Calcium (% Daily Value)', 'Iron
# (% Daily Value)'.

# %%
attributes = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein',
              'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

plt.figure(figsize=(65, 20))
for attribute in attributes:
    plt.subplot(3, 4, attributes.index(attribute) + 1)
    sns.stripplot(x='Category', y=attribute, data=df, jitter=True, palette='Set2', alpha=0.7)


    plt.ylabel('attribute')
    plt.title(f'Strip Plot of {attribute} per Category')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\2100573023.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y=attribute, data=df, jitter=True, palette='Set2', alpha=0.7)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 10
#       6     plt.subplot(3, 4, attributes.index(attribute) + 1)
#       7     sns.stripplot(x='Category', y=attribute, data=df, jitter=True, palette='Set2', alpha=0.7)
# ---> 10     plt.ylabel('attribute')
#      11     plt.title(f'Strip Plot of {attribute} per Category')
#      13 plt.tight_layout()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# **Explanation:**
# - This loop iterates through each attribute and creates a strip plot for each. It uses sns.stripplot to draw a strip plot with the specified   parameters:
# - x='Category': The 'Category' column from the DataFrame is used as the x-axis.
# - y=attribute: The current nutritional attribute is used as the y-axis.
# - data=df: The data is taken from the DataFrame df.
# - jitter=True: Adds a small amount of jitter to the horizontal position of the points to avoid overlap.
# - palette='Set2': Sets the color palette to 'Set2'.
# - alpha=0.7: Sets the transparency of the points.
# - plt.xlabel, plt.ylabel, plt.title: Customize axis labels and the title for each subplot

# %% [markdown]
#  **Task 07**
# > Draw a horizontal bar graph for items in each category against the calories.
# Here is one sample for all items in Beef & Pork, you have to do it for items in each category. Also, write
# your observation.

# %%
df["Category"].value_counts()
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %%
tea_data = df[df['Category'] == 'Coffee & Tea']
plt.figure(figsize=(12, 15))
sns.barplot(x='Calories', y='Item', data=tea_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Coffee & Tea Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\526031689.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=tea_data, palette='viridis')

# %% [markdown]
# > **Observation**
# >- Coffee & Tea: There are 95 items in this category, offering a wide selection of beverages like coffee and tea. Notable Item: Frappe Chocolate Chip (Large) has more calories, more than 700.

# %% [markdown]
# - **For BreakFast Category**

# %%
breakfast_data = df[df['Category'] == 'Breakfast']
plt.figure(figsize=(12, 10))
sns.barplot(x='Calories', y='Item', data=breakfast_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Breakfast Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\1787341498.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=breakfast_data, palette='viridis')

# %% [markdown]
# > **Observation**
# >- Breakfast: There are 42 items in this category, offering a wide selection of beverages like Hotcakes Buiscuits etc. Notable Item: Big breakfast with hotcakes(large biscuits) has more calories, more than 1000.

# %% [markdown]
# **For Smoothies & Shakes**

# %%
Smoothies_data = df[df['Category'] == 'Smoothies & Shakes']
plt.figure(figsize=(12, 8))
sns.barplot(x='Calories', y='Item', data=Smoothies_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Smoothies & Shakes Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\2227750384.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=Smoothies_data, palette='viridis')

# %% [markdown]
# > **Observation**
# > - Smoothies & Shakes: This category has 28 items, showcasing a variety of refreshing smoothies and shakes. Notable item: McFlurry with M&M's Candies(Medium) has more calories, more than 800.

# %% [markdown]
# **For Chicken & Fish**

# %%
chicken_data = df[df['Category'] == 'Chicken & Fish']
plt.figure(figsize=(12, 8))
sns.barplot(x='Calories', y='Item', data=chicken_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Chicken & Fish Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\756652102.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=chicken_data, palette='viridis')

# %% [markdown]
# > **Obserbvation**
# > - Chicken & Fish: Offering 27 items, this category includes a selection of chicken and fish-based dishes.
# >- Notable Item:
# >- Chicken McNuggets (40pcs) is available in this category.
# >- It has more calories

# %% [markdown]
# **For Beverages**

# %%
beverages_data = df[df['Category'] == 'Beverages']
plt.figure(figsize=(12, 5))
sns.barplot(x='Calories', y='Item', data=beverages_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Beverages Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\3761137883.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=beverages_data, palette='viridis')

# %% [markdown]
# >**Observation**
# > Beverages: Similar to Coffee & Tea, the Beverages category boasts 27 items, providing various drink options.
#
# Notable Items:
#
# - Coca-Cola Classic has 140 calories.
# - Sprite (Large) has 220 calories.
# - Minute Maid Orange Juice (Large) has 250 calories.

# %% [markdown]
# **For Beef & Pork**

# %%
beef_pork_data = df[df['Category'] == 'Beef & Pork']
plt.figure(figsize=(12, 8))
sns.barplot(x='Calories', y='Item', data=beef_pork_data, palette='viridis')


plt.title('Horizontal Bar Graph of Items in Beef & Pork Category Against Calories')

plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\1506426800.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=beef_pork_data, palette='viridis')

# %% [markdown]
# >**Observation**
# > Beef & Pork: There are 15 items in this category, featuring a selection of dishes centered around beef and pork.
#
# Notable Items:
#
# - Double Quarter Pounder with Cheese has more calories.

# %% [markdown]
# **For Snacks & Sides**

# %%
Snacks_data = df[df['Category'] == 'Snacks & Sides']
plt.figure(figsize=(12, 5))
sns.barplot(x='Calories', y='Item', data=Snacks_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Snacks & Sides Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\1574121297.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=Snacks_data, palette='viridis')

# %% [markdown]
# >**Observation**
# > Snacks & Sides: With 13 items, this category offers a curated selection of delectable snacks and side dishes.
#
# Notable Item:
#
# Large French Fries has more than 500 calories.

# %% [markdown]
# **For Desserts**

# %%
Desserts_data = df[df['Category'] == 'Desserts']
plt.figure(figsize=(12, 5))
sns.barplot(x='Calories', y='Item', data=Desserts_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Desserts Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\3622503511.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=Desserts_data, palette='viridis')

# %% [markdown]
# >**Observation**
# > Desserts: The Desserts category has 7 items, perfect for those with a sweet tooth.
# Notable Items with more than 300 calories:
#
# - Hot Fudge Sundae has more than 300 calories (330 calories).
# - Hot Caramel Sundae has more than 300 calories (340 calories).

# %% [markdown]
# **For Salads**

# %%
Salads_data = df[df['Category'] == 'Salads']
plt.figure(figsize=(12, 5))
sns.barplot(x='Calories', y='Item', data=Salads_data, palette='viridis')

plt.title('Horizontal Bar Graph of Items in Salads Category Against Calories')
plt.show()
# Out:
# C:\Users\4G Traders\AppData\Local\Temp\ipykernel_7912\2225725755.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Calories', y='Item', data=Salads_data, palette='viridis')

# %% [markdown]
# >**Observation**
# > Salads: Featuring 6 items, the Salads category provides healthier alternatives with a variety of salad choices.
#
# Notable Item with more than 400 calories:
#
# Premium Southwest Salad with Crispy Chicken has more than 400 calories (450 calories).
